# %%
import json
import couchdb
import requests

# authentication
admin = 'admin'
password = 'admin'
url = f'http://{admin}:{password}@172.26.135.221:5984/'

# get couchdb instance
couch = couchdb.Server(url)

# indicate the db name

tweetTopic_db = couch['processed_tweets']

def test():
    result = tweetTopic_db.view('countEachTopic/countTopic', group=True)

    # Convert the result to a list of dictionaries
    suburbs = [{'Suburb': row.key, 'total_facilities': row.value} for row in result]
    # [{'Suburb': ['Abbotsford', 'arts_&_culture'], 'total_facilities': 7}, {'Suburb': ['Abbotsford', 'business_&_entrepreneurs'], 'total_facilities': 5}]
    suburb_info = {}

    for item in suburbs:
        suburb, topic = item['Suburb']
        count = item['total_facilities']

        if suburb not in suburb_info:
            suburb_info[suburb] = {'total_tweets': 0, 'topics': {}}

        suburb_info[suburb]['total_tweets'] += count

        if topic not in suburb_info[suburb]['topics']:
            suburb_info[suburb]['topics'][topic] = 0

        suburb_info[suburb]['topics'][topic] += count

    with open('topic_proportions.json', 'w') as json_file:
        json.dump(suburb_info, json_file)

test()

# %%
with open("/Users/rex/Desktop/Comp90024_CCC/Assignment2/Data/topic_proportions.json", "r") as tmp:
    tmp1 = json.load(tmp)

cnttmp = 0
for i, v in tmp1.items():
    cnttmp += v["total_tweets"]
print(cnttmp)
# Out:
# 823470

# %%
result_CNTTWT = tweetTopic_db.view('countTweets/countTweets', group=True)

# Convert the result to a list of dictionaries
ttwt = [{'Suburb': row.key, 'total_twt': row.value} for row in result_CNTTWT]
# [{'Suburb': ['Abbotsford', 'arts_&_culture'], 'total_facilities': 7}, {'Suburb': ['Abbotsford', 'business_&_entrepreneurs'], 'total_facilities': 5}]
print(ttwt)
# Out:
# [{'Suburb': 'Abbotsford', 'total_twt': 70}, {'Suburb': 'Aberfeldie', 'total_twt': 2}, {'Suburb': 'Ada', 'total_twt': 2}, {'Suburb': 'Aintree', 'total_twt': 47}, {'Suburb': 'Aire Valley', 'total_twt': 3}, {'Suburb': 'Aireys Inlet', 'total_twt': 2}, {'Suburb': 'Airport West', 'total_twt': 10}, {'Suburb': 'Albert Park', 'total_twt': 283}, {'Suburb': 'Albion', 'total_twt': 6}, {'Suburb': 'Alexandra', 'total_twt': 58}, {'Suburb': 'Alfredton', 'total_twt': 7}, {'Suburb': 'Allansford', 'total_twt': 4}, {'Suburb': 'Alphington', 'total_twt': 7}, {'Suburb': 'Altona', 'total_twt': 10}, {'Suburb': 'Altona Meadows', 'total_twt': 29}, {'Suburb': 'Altona North', 'total_twt': 10}, {'Suburb': 'Amphitheatre', 'total_twt': 1}, {'Suburb': 'Anglesea', 'total_twt': 232}, {'Suburb': 'Apollo Bay', 'total_twt': 360}, {'Suburb': 'Apsley', 'total_twt': 2}, {'Suburb': 'Arapiles', 'total_twt': 1}, {'Suburb': 'Ararat', 'total_twt': 1130}, {'Suburb': 'Arawata', 'total_twt': 1}, {'Suburb': 'Arbuckle', 'total_twt': 2}, {'Suburb': 'Arcadia', 'total_twt': 1}, {'Suburb': 'Archerton', 'total_twt': 4}, {'Suburb': 'Archies Creek', 'total_twt': 2}, {'Suburb': 'Ardeer', 'total_twt': 8}, {'Suburb': 'Ardmona', 'total_twt': 1}, {'Suburb': 'Armadale', 'total_twt': 17}, {'Suburb': 'Armstrong Creek', 'total_twt': 5}, {'Suburb': 'Arthurs Seat', 'total_twt': 23}, {'Suburb': 'Ascot', 'total_twt': 5}, {'Suburb': 'Ascot Vale', 'total_twt': 11}, {'Suburb': 'Ashburton', 'total_twt': 1}, {'Suburb': 'Ashwood', 'total_twt': 3}, {'Suburb': 'Aspendale', 'total_twt': 2}, {'Suburb': 'Avalon', 'total_twt': 16}, {'Suburb': 'Avenel', 'total_twt': 23}, {'Suburb': 'Avoca', 'total_twt': 84}, {'Suburb': 'Avon Plains', 'total_twt': 2}, {'Suburb': 'Avondale Heights', 'total_twt': 6}, {'Suburb': 'Axedale', 'total_twt': 7}, {'Suburb': 'Bacchus Marsh', 'total_twt': 337}, {'Suburb': 'Badger Creek', 'total_twt': 4}, {'Suburb': 'Bairnsdale', 'total_twt': 626}, {'Suburb': 'Bakery Hill', 'total_twt': 1}, {'Suburb': 'Balaclava', 'total_twt': 16}, {'Suburb': 'Ballan', 'total_twt': 25}, {'Suburb': 'Ballarat Central', 'total_twt': 19407}, {'Suburb': 'Ballarat East', 'total_twt': 1}, {'Suburb': 'Ballarat North', 'total_twt': 1}, {'Suburb': 'Ballyrogan', 'total_twt': 1}, {'Suburb': 'Balmattum', 'total_twt': 3}, {'Suburb': 'Balnarring', 'total_twt': 14}, {'Suburb': 'Balnarring Beach', 'total_twt': 1}, {'Suburb': 'Balook', 'total_twt': 4}, {'Suburb': 'Balwyn', 'total_twt': 16}, {'Suburb': 'Balwyn North', 'total_twt': 14}, {'Suburb': 'Bambra', 'total_twt': 1}, {'Suburb': 'Bandiana', 'total_twt': 1}, {'Suburb': 'Bangholme', 'total_twt': 1}, {'Suburb': 'Bannockburn', 'total_twt': 23}, {'Suburb': 'Baranduda', 'total_twt': 12}, {'Suburb': 'Barjarg', 'total_twt': 2}, {'Suburb': 'Barmah', 'total_twt': 2}, {'Suburb': 'Barnawartha', 'total_twt': 2}, {'Suburb': 'Barnawartha North', 'total_twt': 3}, {'Suburb': 'Barongarook West', 'total_twt': 2}, {'Suburb': 'Barwite', 'total_twt': 1}, {'Suburb': 'Barwon Heads', 'total_twt': 2}, {'Suburb': 'Batesford', 'total_twt': 10}, {'Suburb': 'Baw Baw', 'total_twt': 2}, {'Suburb': 'Baw Baw Village', 'total_twt': 13}, {'Suburb': 'Baxter', 'total_twt': 6}, {'Suburb': 'Bayles', 'total_twt': 24}, {'Suburb': 'Bayswater', 'total_twt': 4}, {'Suburb': 'Bayswater North', 'total_twt': 5}, {'Suburb': 'Beaconsfield', 'total_twt': 1}, {'Suburb': 'Beaconsfield Upper', 'total_twt': 6}, {'Suburb': 'Bealiba', 'total_twt': 4}, {'Suburb': 'Beaufort', 'total_twt': 49}, {'Suburb': 'Beaumaris', 'total_twt': 5}, {'Suburb': 'Beech Forest', 'total_twt': 9}, {'Suburb': 'Beechworth', 'total_twt': 277}, {'Suburb': 'Belgrave', 'total_twt': 12}, {'Suburb': 'Belgrave Heights', 'total_twt': 1}, {'Suburb': 'Bell Park', 'total_twt': 1}, {'Suburb': 'Bell Post Hill', 'total_twt': 1}, {'Suburb': 'Bellarine', 'total_twt': 7}, {'Suburb': 'Bellbrae', 'total_twt': 7}, {'Suburb': 'Bellbridge', 'total_twt': 2}, {'Suburb': 'Bellfield', 'total_twt': 4}, {'Suburb': 'Bells Beach', 'total_twt': 21}, {'Suburb': 'Belmont', 'total_twt ...

# %%
import json


ttwt_dict = {item['Suburb']: item['total_twt'] for item in ttwt}

for suburb in tmp1:
    if suburb in ttwt_dict:
        tmp1[suburb]['uniquetwts'] = ttwt_dict[suburb]
        del tmp1[suburb]['total_tweets']

with open('updated_topic_prop.json', 'w') as f:
    json.dump(tmp1, f, indent=4)

# %%
with open('updated_topic_prop.json', 'r') as f:
    rrr = json.load(f)

## total suburbs in twitter file
cnt = 0
for i in rrr:
    cnt+=1
print(cnt)
# Out:
# 1272

# %%
import json



for suburb, info in rrr.items():
    for topic, count in info['topics'].items():
        info['topics'][topic] = count / info['uniquetwts']

with open('updated_topic_prop_v1.json', 'w') as f:
    json.dump(rrr, f, indent=4)

# %%
## Select the evg sentiment score
tweetSenti_db = couch['tweets_processed2']

result_senti = tweetSenti_db.view('avgSentiment/avgSentiment', group=True)

# Convert the result to a list of dictionaries
ttwt_senti = [{'Suburb': row.key, 'senti': row.value} for row in result_senti]
# [{'Suburb': ['Abbotsford', 'arts_&_culture'], 'total_facilities': 7}, {'Suburb': ['Abbotsford', 'business_&_entrepreneurs'], 'total_facilities': 5}]
print(ttwt_senti)
# Out:
# [{'Suburb': 'Abbotsford', 'senti': 0.14214387185295863}, {'Suburb': 'Aberfeldie', 'senti': 0.1925531914893617}, {'Suburb': 'Aintree', 'senti': 0.008555641291337245}, {'Suburb': 'Aire Valley', 'senti': 0.16666666666666669}, {'Suburb': 'Aireys Inlet', 'senti': 0.19696969696969696}, {'Suburb': 'Airport West', 'senti': 0.21958175242875289}, {'Suburb': 'Albert Park', 'senti': 0.17576472457407744}, {'Suburb': 'Albion', 'senti': 0.19798976608187135}, {'Suburb': 'Alexandra', 'senti': 0.13817785897552565}, {'Suburb': 'Alfredton', 'senti': -0.27897717807762784}, {'Suburb': 'Allansford', 'senti': 0.1225}, {'Suburb': 'Alphington', 'senti': 0.19934640522875818}, {'Suburb': 'Altona', 'senti': 0.07663764371044451}, {'Suburb': 'Altona Meadows', 'senti': 0.010507163749644957}, {'Suburb': 'Altona North', 'senti': 0.056553927484765426}, {'Suburb': 'Anglesea', 'senti': 0.1262875797583876}, {'Suburb': 'Apollo Bay', 'senti': 0.20956628679625433}, {'Suburb': 'Apsley', 'senti': 0.014050387596899225}, {'Suburb': 'Ararat', 'senti': 0.06934665663787787}, {'Suburb': 'Archerton', 'senti': 0.034913234913234906}, {'Suburb': 'Ardeer', 'senti': 0.15830061328673722}, {'Suburb': 'Armadale', 'senti': 0.19011581000997477}, {'Suburb': 'Armstrong Creek', 'senti': 0.055346513605442176}, {'Suburb': 'Arthurs Seat', 'senti': 0.09079289653937993}, {'Suburb': 'Ascot', 'senti': 0.1911922663802363}, {'Suburb': 'Ascot Vale', 'senti': 0.10839295558999534}, {'Suburb': 'Ashburton', 'senti': 0.20833333333333334}, {'Suburb': 'Ashwood', 'senti': -0.04}, {'Suburb': 'Aspendale', 'senti': -0.125}, {'Suburb': 'Avalon', 'senti': 0.17347274436090224}, {'Suburb': 'Avenel', 'senti': 0.12143992143543793}, {'Suburb': 'Avoca', 'senti': -0.13373346054079388}, {'Suburb': 'Avondale Heights', 'senti': 0.14742883868523254}, {'Suburb': 'Axedale', 'senti': -0.29411764705882354}, {'Suburb': 'Bacchus Marsh', 'senti': 0.2649793914741833}, {'Suburb': 'Badger Creek', 'senti': -0.10256410256410256}, {'Suburb': 'Bairnsdale', 'senti': 0.04646092716647429}, {'Suburb': 'Bakery Hill', 'senti': 0.0425531914893617}, {'Suburb': 'Balaclava', 'senti': 0.045170120260864366}, {'Suburb': 'Ballan', 'senti': 0.10225428347132369}, {'Suburb': 'Ballarat Central', 'senti': -0.030279190184097755}, {'Suburb': 'Ballarat East', 'senti': 0.42857142857142855}, {'Suburb': 'Ballyrogan', 'senti': -0.18181818181818182}, {'Suburb': 'Balmattum', 'senti': -0.11764705882352941}, {'Suburb': 'Balnarring', 'senti': 0.18205404509283818}, {'Suburb': 'Balnarring Beach', 'senti': 0.2727272727272727}, {'Suburb': 'Balwyn', 'senti': 0.06707291270110963}, {'Suburb': 'Balwyn North', 'senti': 0.1384519352866311}, {'Suburb': 'Bangholme', 'senti': 0.18604651162790697}, {'Suburb': 'Bannockburn', 'senti': 0.11805971358174733}, {'Suburb': 'Baranduda', 'senti': 0.0578729488160829}, {'Suburb': 'Barjarg', 'senti': -0.125}, {'Suburb': 'Barmah', 'senti': 0.1}, {'Suburb': 'Barnawartha', 'senti': 0.04691762138570649}, {'Suburb': 'Barnawartha North', 'senti': 0.14583333333333334}, {'Suburb': 'Barongarook West', 'senti': 0.46033653846153844}, {'Suburb': 'Barwite', 'senti': 0.23076923076923078}, {'Suburb': 'Batesford', 'senti': 0.23866427216650005}, {'Suburb': 'Baw Baw', 'senti': 0.09117647058823529}, {'Suburb': 'Baw Baw Village', 'senti': 0.016666666666666663}, {'Suburb': 'Baxter', 'senti': 0.07033613445378151}, {'Suburb': 'Bayles', 'senti': 0.11590743628467413}, {'Suburb': 'Bayswater', 'senti': 0.23095399698340874}, {'Suburb': 'Bayswater North', 'senti': 0.17800925925925926}, {'Suburb': 'Beaconsfield', 'senti': -0.09090909090909091}, {'Suburb': 'Beaconsfield Upper', 'senti': 0.13748597081930414}, {'Suburb': 'Bealiba', 'senti': 0.19235593997021425}, {'Suburb': 'Beaufort', 'senti': 0.23267519245324653}, {'Suburb': 'Beaumaris', 'senti': 0.0992063492063492}, {'Suburb': 'Beech Forest', 'senti': 0.18374649566986723}, {'Suburb': 'Beechworth', 'senti': 0.08105633877373815}, {'Suburb': 'Belgrave', 'senti': -0.023353086124825242}, {'Suburb': 'Belgrave Heights', 'senti':  ...

# %%
import json

with open('updated_topic_prop_v1.json', 'r') as f:
    topic_data = json.load(f)


senti_dict = {item['Suburb']: item['senti'] for item in ttwt_senti}

for suburb in topic_data.keys():
    if suburb in senti_dict:
        topic_data[suburb]['avgsenti'] = senti_dict[suburb]

with open('updated_topic_prop_v2.json', 'w') as f:
    json.dump(topic_data, f, indent=4)
