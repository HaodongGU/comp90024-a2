# %%
import json

file_path = 'E:\CCC\datasource-SNAMUTS-UoM_AURIN_DB_snamuts_activity_nodes_2016.json'

with open(file_path, 'r') as file:
    data = file.read()

    json_data = json.loads(data)

# %%
for i in json_data:
    print(i)
# Out:
# type
# features
# totalFeatures
# numberMatched
# numberReturned
# timeStamp
# crs
# bbox

# %%
transport_feature = json_data['features']
print(type(transport_feature))
print(len(transport_feature))
# Out:
# <class 'list'>
# 654

# %%
melb_transport_feature = []
for area_transport_feature in transport_feature:
    city = area_transport_feature['properties']['city']
    if city== 'Melbourne':
        melb_transport_feature.append(area_transport_feature)
        print(area_transport_feature['properties']['node'])
# Out:
# Airport West
# Alamein
# Altona
# Armadale
# Arts Precinct
# Ascot Vale (Union Rd)
# Bentleigh
# Box Hill
# Docklands (Victoria Harbour)
# Broadmeadows
# Brunswick (Sydney Rd)
# Bundoora RMIT
# Burnley
# Camberwell Station
# Camberwell Junction
# Carlton (Lygon St)
# Carnegie
# Caulfield
# Chelsea
# Cheltenham
# Clayton
# Clifton Hill Station
# Clifton Hill (Queens Pde)
# Coburg (Sydney Rd)
# Coburg Station
# Collingwood (Smith St)
# Crown Casino
# Dandenong
# Deakin University
# Docklands (Harbour Esplanade)
# Docklands (Waterfront City)
# Doncaster
# South Caulfield
# East Brunswick (Lygon St)
# East Brunswick (Nicholson St)
# East Burwood (Blackburn Rd)
# East Burwood (Springvale Rd)
# East Preston
# East Richmond
# Elizabeth-Collins
# Eltham
# Emerald Hill
# Essendon
# Exhibition-Flinders
# Fitzroy (Brunswick St)
# Fitzroy (Nicholson St)
# Flagstaff
# Flemington Bridge
# Flinders Street Station
# Footscray
# Frankston
# Gardenvale
# Gardiner
# Glen Iris
# Glen Waverley
# ...

# %%
melb_transport_feature
# Out:
# [{'type': 'Feature',
#   'id': 'snamuts_activity_nodes_2016.348',
#   'geometry': {'type': 'MultiPoint',
#    'coordinates': [[144.889906, -37.713243]]},
#   'geometry_name': 'wkb_geometry',
#   'properties': {'node': 'Airport West',
#    'city': 'Melbourne',
#    'degree_centrality': 0.9414634,
#    'closeness_centrality': 80.8192,
#    'contour_catchment': 1.9089268,
#    'nodal_betweenness': 4.816052,
#    'nodal_connectivity': 4.491,
#    'nodal_resilience': -4.33048,
#    'composite_index': 9.720795,
#    'transfer_propensity': 2.7252767,
#    'ogc_fid': 348},
#   'bbox': [144.889906, -37.713243, 144.889906, -37.713243]},
#  {'type': 'Feature',
#   'id': 'snamuts_activity_nodes_2016.349',
#   'geometry': {'type': 'MultiPoint',
#    'coordinates': [[145.079504, -37.868134]]},
#   'geometry_name': 'wkb_geometry',
#   'properties': {'node': 'Alamein',
#    'city': 'Melbourne',
#    'degree_centrality': 1.8439025,
#    'closeness_centrality': 75.82595,
# ...
